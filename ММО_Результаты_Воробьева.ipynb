# %% [markdown]
# <a href="https://colab.research.google.com/github/krimplessy/Machine_Learning/blob/main/%D0%9C%D0%9C%D0%9E_%D0%A0%D0%B5%D0%B7%D1%83%D0%BB%D1%8C%D1%82%D0%B0%D1%82%D1%8B_%D0%92%D0%BE%D1%80%D0%BE%D0%B1%D1%8C%D0%B5%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Результаты сравнения методов

# %% [markdown]
# Таблица сравнения методов: https://docs.google.com/spreadsheets/d/1r_ya-ffaZbGDUfDgX6bE2arHYsznKMbxwrpe14XLJ-M/edit?usp=sharing

# %% [markdown]
# ![Снимок экрана 2023-12-20 в 14.32.32.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2023-12-20 в 14.35.22.png](data:image/png;base64,...)

# %% [markdown]
# Лучшим методом для моей выборки является Наивный Байесовский классификатор. При random_state = 14:
#
# * качество на обучениии - 75%.
# * качество на контроле - 80%.
#
# Основные преимущества данного метода на моей выборке - простота реализации и низкие вычислительные затраты при обучении и классификации, а также малое количество данных для обучения, необходимых для оценки параметров, требуемых для классификации.
